# %%
import csv
from datetime import datetime
import numpy as np
import pandas as pd
import time 
import os
from os import path
from glob import glob

import ijson
from tqdm import tqdm

# %% [markdown]
# # Read from csv

# %%
def fixTimezone(df):
    # Convert Timestamp to datetime
    df.date_time.dt.to_pydatetime()
    # + 9hours
    jst = df.date_time.dt.to_pydatetime() + dt.timedelta(hours = 9)
    # Add Column
    df['date_time'] = jst

    # Adjustment
    df['year'] = df['date_time'].dt.year
    df['month'] = df['date_time'].dt.month
    df['day'] = df['date_time'].dt.day
    df['hour'] = df['date_time'].dt.hour
    df['time'] = df['date_time'].dt.time
    df.rename(columns={'date_time': 'date'})

# %%
# Read ORs
zip_dir  = "../data/new_dfs"
csvfiles = glob(os.path.join(zip_dir, 'dfor*'))
dfors = []
for csvfile in csvfiles:
    df = pd.read_csv(csvfile, parse_dates=[['date', 'time']]).drop('Unnamed: 0', axis=1)
    fixTimezone(df)
    dfors.append(df)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-206-8ad6dd2e2a17> in <module>
#       5 for csvfile in csvfiles:
#       6     df = pd.read_csv(csvfile, parse_dates=[['date', 'time']]).drop('Unnamed: 0', axis=1)
# ----> 7     fixTimezone(df)
#       8     dfors.append(df)
#
# <ipython-input-205-27ba9c52370b> in fixTimezone(df)
#      12     df['day'] = df['date_time'].dt.day
#      13     df['hour'] = df['date_time'].dt.hour
# ---> 14     df['time'] = df['date_time'].dt.time
#      15     df.rename(columns={'date_time': 'date'})
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/accessor.py in _getter(self)
#      83         def _create_delegator_property(name):
#      84             def _getter(self):
# ---> 85                 return self._delegate_property_get(name)
#      86
#      87             def _setter(self, new_values):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/accessors.py in _delegate_property_get(self, name)
# ...

# %%
import datetime as dt

# %%
d0['year'] = d0['date_time'].dt.year
d0['month'] = d0['date_time'].dt.month
d0['day'] = d0['date_time'].dt.day
d0['hour'] = d0['date_time'].dt.hour
d0['time'] = d0['date_time'].dt.time
d0.rename(columns={'date_time': 'date'})
# Out:
#                       date              user_id  \
# 0      2020-02-29 23:59:58  1075754901160914944
# 1      2020-02-29 23:59:58            155171688
# 2      2020-02-29 23:59:58           2586924805
# 3      2020-02-29 23:59:58            133191462
# 4      2020-02-29 23:59:58           1560456696
# ...                    ...                  ...
# 971275 2020-02-27 02:24:04  1221474447170818048
# 971276 2020-02-27 02:24:04  1145499978585931776
# 971277 2020-02-27 02:24:03           3068170392
# 971278 2020-02-27 02:24:01            581885933
# 971279 2020-02-27 02:24:01  1225000023307370496
#
#                                                     tweet  RT_flag  year  \
# 0       今夜は久しぶりに お月様を見れましたが、少し雲がかかってボンヤリ月でした☁🌛☁🔭(ㆁωㆁ*)...    False  2020
# 1        長期的にはジャイロに慣れた方が良いんだけど、今回の大会しか見てないのかなってちょっと悲しくなった    False  2020
# 2                    不二先輩の誕生日で言いたいことたくさんあるけど、上手くまとまらないね😭😭    False  2020
# 3       フェルナンドと遊ぼう・華麗なるフェルナンド・フェルナンドの憂鬱・翔べフェルナンド・Oh! フ...    False  2020
# ...
